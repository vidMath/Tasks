# %%
#Elaborate on any one particular metric/characteristic that would be of particular benefit in increasing contractor productivity

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df2 = pd.read_csv('Contractors Data Dump.xlsx - Worker Data.csv')

#Create a new function:
def bool_to_num(x):
    if x is True:
        return 1
    elif x is False:
        return 0
    else:
        return x
    
df2['sum'] = df2['has_passed_logical_ability']+df2['has_passed_reading_comprehension']+df2['has_passed_general_awareness']+df2['has_passed_attention_to_detail']+df2['has_passed_pattern_recog']
df2.boxplot(column=['qualifiers_rejects','qualifiers_approved'],by='sum',figsize=[20,5])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000000077DA550>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000009700128>], dtype=object)

# %%
temp1 = df2.pivot_table(values=['qualifiers_approved','qualifiers_re_attempts','qualifiers_rejects',
                               'voice_approved','voice_rejects','voice_re_attempts',
                               'sd_approved','sd_rejects','sd_re_attempts',
                               'ts_approved','ts_rejects','ts_re_attempts',
                               'other_data_rejects','other_data_re_attempts','other_data_approved'],
                        index=['has_passed_logical_ability'])
print temp1

'''temp4 = df2.pivot_table(values=['voice_approved','voice_rejects','voice_re_attempts'],index=['has_passed_logical_ability'])
print temp4

temp4 = df2.pivot_table(values=['sd_approved','sd_rejects','sd_re_attempts'],index=['has_passed_logical_ability'])
print temp4

temp4 = df2.pivot_table(values=['ts_approved','ts_rejects','ts_re_attempts'],index=['has_passed_logical_ability'])
print temp4

temp4 = df2.pivot_table(values=['other_data_rejects','other_data_re_attempts','other_data_approved'],index=['has_passed_logical_ability'])
print temp4'''
# Out:
#                             other_data_approved  other_data_re_attempts  \
# has_passed_logical_ability
# False                                859.852751              137.355987
# True                                2759.590643              334.403509
#
#                             other_data_rejects  qualifiers_approved  \
# has_passed_logical_ability
# False                                16.297735            17.399676
# True                                 30.760234            65.660819
#
#                             qualifiers_re_attempts  qualifiers_rejects  \
# has_passed_logical_ability
# False                                    24.985437            9.831715
# True                                     42.897661            9.406433
#
#                             sd_approved  sd_re_attempts  sd_rejects  \
# has_passed_logical_ability
# False                        314.543689       38.789644    1.391586
# True                         999.464912       93.695906    5.868421
#
# ...

# %%
temp2 = df2.pivot_table(values=['qualifiers_approved','qualifiers_re_attempts','qualifiers_rejects',
                               'voice_approved','voice_rejects','voice_re_attempts',
                               'sd_approved','sd_rejects','sd_re_attempts',
                               'ts_approved','ts_rejects','ts_re_attempts',
                               'other_data_rejects','other_data_re_attempts','other_data_approved'],
                        index=['has_passed_reading_comprehension'])
print temp2

'''temp4 = df2.pivot_table(values=['voice_approved','voice_rejects','voice_re_attempts'],index=['has_passed_reading_comprehension'],aggfunc=np.sum)
print temp4

temp4 = df2.pivot_table(values=['sd_approved','sd_rejects','sd_re_attempts'],index=['has_passed_reading_comprehension'],aggfunc=np.sum)
print temp4

temp4 = df2.pivot_table(values=['ts_approved','ts_rejects','ts_re_attempts'],index=['has_passed_reading_comprehension'],aggfunc=np.sum)
print temp4

temp4 = df2.pivot_table(values=['other_data_rejects','other_data_re_attempts','other_data_approved'],index=['has_passed_reading_comprehension'],aggfunc=np.sum)
print temp4'''
# Out:
#                                   other_data_approved  other_data_re_attempts  \
# has_passed_reading_comprehension
# False                                      868.722132              138.003231
# True                                      2746.724340              333.043988
#
#                                   other_data_rejects  qualifiers_approved  \
# has_passed_reading_comprehension
# False                                      16.313409            17.468498
# True                                       30.809384            65.718475
#
#                                   qualifiers_re_attempts  qualifiers_rejects  \
# has_passed_reading_comprehension
# False                                          25.053312            9.836834
# True                                           42.950147            9.404692
#
#                                   sd_approved  sd_re_attempts  sd_rejects  \
# has_passed_reading_comprehension
# ...

# %%
temp3 = df2.pivot_table(values=['qualifiers_approved','qualifiers_re_attempts','qualifiers_rejects',
                                'voice_approved','voice_rejects','voice_re_attempts',
                                'sd_approved','sd_rejects','sd_re_attempts',
                                'ts_approved','ts_rejects','ts_re_attempts',
                                'other_data_rejects','other_data_re_attempts','other_data_approved'],
                        index=['has_passed_general_awareness'])
print temp3

'''temp3 = df2.pivot_table(values=['voice_approved','voice_rejects','voice_re_attempts'],index=['has_passed_general_awareness'])
print temp3

temp4 = df2.pivot_table(values=['sd_approved','sd_rejects','sd_re_attempts'],index=['has_passed_general_awareness'])
print temp3

temp4 = df2.pivot_table(values=['ts_approved','ts_rejects','ts_re_attempts'],index=['has_passed_general_awareness'])
print temp3

temp4 = df2.pivot_table(values=['other_data_rejects','other_data_re_attempts','other_data_approved'],index=['has_passed_general_awareness'])
print temp3'''
# Out:
#                               other_data_approved  other_data_re_attempts  \
# has_passed_general_awareness
# False                                  856.716578              138.139037
# True                                  2502.252500              305.735000
#
#                               other_data_rejects  qualifiers_approved  \
# has_passed_general_awareness
# False                                  17.016043            14.746881
# True                                   27.680000            62.490000
#
#                               qualifiers_re_attempts  qualifiers_rejects  \
# has_passed_general_awareness
# False                                      24.420677           10.160428
# True                                       41.197500            9.015000
#
#                               sd_approved  sd_re_attempts  sd_rejects  \
# has_passed_general_awareness
# False                          321.235294       42.509804    1.540107
# ...

# %%
temp4 = df2.pivot_table(values=['qualifiers_approved','qualifiers_re_attempts','qualifiers_rejects',
                               'voice_approved','voice_rejects','voice_re_attempts',
                               'sd_approved','sd_rejects','sd_re_attempts',
                               'ts_approved','ts_rejects','ts_re_attempts',
                               'other_data_rejects','other_data_re_attempts','other_data_approved'],
                        index=['has_passed_attention_to_detail'])
print temp4

'''temp4 = df2.pivot_table(values=['voice_approved','voice_rejects','voice_re_attempts'],index=['has_passed_attention_to_detail'])
print temp4

temp4 = df2.pivot_table(values=['sd_approved','sd_rejects','sd_re_attempts'],index=['has_passed_attention_to_detail'])
print temp4

temp4 = df2.pivot_table(values=['ts_approved','ts_rejects','ts_re_attempts'],index=['has_passed_attention_to_detail'])
print temp4

temp4 = df2.pivot_table(values=['other_data_rejects','other_data_re_attempts','other_data_approved'],index=['has_passed_attention_to_detail'])
print temp4'''
# Out:
#                                 other_data_approved  other_data_re_attempts  \
# has_passed_attention_to_detail
# False                                    838.171026              126.287726
# True                                    2295.146552              295.312500
#
#                                 other_data_rejects  qualifiers_approved  \
# has_passed_attention_to_detail
# False                                    16.575453            16.074447
# True                                     26.681034            54.482759
#
#                                 qualifiers_re_attempts  qualifiers_rejects  \
# has_passed_attention_to_detail
# False                                        22.042254           10.239437
# True                                         41.431034            9.088362
#
#                                 sd_approved  sd_re_attempts  sd_rejects  \
# has_passed_attention_to_detail
# False                            318.911469       41.879276    1.412475
# ...

# %%
temp5 = df2.pivot_table(values=['qualifiers_approved','qualifiers_re_attempts','qualifiers_rejects',
                               'voice_approved','voice_rejects','voice_re_attempts',
                               'sd_approved','sd_rejects','sd_re_attempts',
                               'ts_approved','ts_rejects','ts_re_attempts',
                               'other_data_rejects','other_data_re_attempts','other_data_approved'],index=['has_passed_pattern_recog'])
print temp5

'''temp5 = df2.pivot_table(values=['voice_approved','voice_rejects','voice_re_attempts'],index=['has_passed_pattern_recog'])
print temp5

temp5 = df2.pivot_table(values=['sd_approved','sd_rejects','sd_re_attempts'],index=['has_passed_pattern_recog'])
print temp5

temp5 = df2.pivot_table(values=['ts_approved','ts_rejects','ts_re_attempts'],index=['has_passed_pattern_recog'])
print temp5

temp5 = df2.pivot_table(values=['other_data_rejects','other_data_re_attempts','other_data_approved'],index=['has_passed_pattern_recog'])
print temp5'''
# Out:
#                           other_data_approved  other_data_re_attempts  \
# has_passed_pattern_recog
# False                              867.703896              140.779221
# True                              1992.105903              252.760417
#
#                           other_data_rejects  qualifiers_approved  \
# has_passed_pattern_recog
# False                              16.607792            13.750649
# True                               24.694444            48.567708
#
#                           qualifiers_re_attempts  qualifiers_rejects  \
# has_passed_pattern_recog
# False                                  22.901299            9.831169
# True                                   37.086806            9.585069
#
#                           sd_approved  sd_re_attempts  sd_rejects  \
# has_passed_pattern_recog
# False                      361.636364       43.690909    1.451948
# True                       693.847222       68.364583    4.008681
#
# ...

# %%
df2['sum_rejects'] = df2['qualifiers_rejects']+df2['voice_rejects']+df2['sd_rejects']+df2['ts_rejects']+df2['other_data_rejects']
#print df2['sum']
#df2.boxplot(column='sum_approved',by='has_passed_logical_ability')
temp = df2.pivot_table(values='sum_rejects',index=['has_passed_logical_ability'])
print temp
temp = df2.pivot_table(values='sum_rejects',index=['has_passed_reading_comprehension'])
print temp
temp = df2.pivot_table(values='sum_rejects',index=['has_passed_general_awareness'])
print temp
temp = df2.pivot_table(values='sum_rejects',index=['has_passed_attention_to_detail'])
print temp
temp = df2.pivot_table(values='sum_rejects',index=['has_passed_pattern_recog'])
print temp
# Out:
# has_passed_logical_ability
# False    29.843042
# True     51.116959
# Name: sum_rejects, dtype: float64
# has_passed_reading_comprehension
# False    29.862682
# True     51.184751
# Name: sum_rejects, dtype: float64
# has_passed_general_awareness
# False    31.11943
# True     46.27250
# Name: sum_rejects, dtype: float64
# has_passed_attention_to_detail
# False    30.657948
# True     44.676724
# Name: sum_rejects, dtype: float64
# has_passed_pattern_recog
# False    30.189610
# True     42.263889
# Name: sum_rejects, dtype: float64

# %%
df2['sum_approved'] = df2['qualifiers_approved']+df2['voice_approved']+df2['sd_approved']+df2['ts_approved']+df2['other_data_approved']
#print df2['sum']
#df2.boxplot(column='sum_approved',by='has_passed_logical_ability')
temp = df2.pivot_table(values='sum_approved',index=['has_passed_logical_ability'])
print temp
temp = df2.pivot_table(values='sum_approved',index=['has_passed_reading_comprehension'])
print temp
temp = df2.pivot_table(values='sum_approved',index=['has_passed_general_awareness'])
print temp
temp = df2.pivot_table(values='sum_approved',index=['has_passed_attention_to_detail'])
print temp
temp = df2.pivot_table(values='sum_approved',index=['has_passed_pattern_recog'])
print temp

'''df2['sum_rejects'] = df2['qualifiers_rejects']+df2['voice_rejects']+df2['sd_rejects']+df2['ts_rejects']+df2['other_data_rejects']
#print df2['sum']
df2.boxplot(column='sum_rejects',by='has_passed_logical_ability')
temp = df2.pivot_table(values='sum_rejects',index=['has_passed_logical_ability'],aggfunc=np.sum)
print temp'''
# Out:
# has_passed_logical_ability
# False    1461.529126
# True     4516.491228
# Name: sum_approved, dtype: float64
# has_passed_reading_comprehension
# False    1474.195477
# True     4491.299120
# Name: sum_approved, dtype: float64
# has_passed_general_awareness
# False    1453.160428
# True     4104.860000
# Name: sum_approved, dtype: float64
# has_passed_attention_to_detail
# False    1466.299799
# True     3725.034483
# Name: sum_approved, dtype: float64
# has_passed_pattern_recog
# False    1496.768831
# True     3265.470486
# Name: sum_approved, dtype: float64
# "df2['sum_rejects'] = df2['qualifiers_rejects']+df2['voice_rejects']+df2['sd_rejects']+df2['ts_rejects']+df2['other_data_rejects']\n#print df2['sum']\ndf2.boxplot(column='sum_rejects',by='has_passed_logical_ability')\ntemp = df2.pivot_table(values='sum_rejects',index=['has_passed_logical_ability'],aggfunc=np.sum)\nprint temp"

# %%
df2['sum_re_attempts'] = df2['qualifiers_re_attempts']+df2['voice_re_attempts']+df2['sd_re_attempts']+df2['ts_re_attempts']+df2['other_data_re_attempts']
#print df2['sum']
#df2.boxplot(column='sum_approved',by='has_passed_logical_ability')
temp = df2.pivot_table(values='sum_re_attempts',index=['has_passed_logical_ability'])
print temp
temp = df2.pivot_table(values='sum_re_attempts',index=['has_passed_reading_comprehension'])
print temp
temp = df2.pivot_table(values='sum_re_attempts',index=['has_passed_general_awareness'])
print temp
temp = df2.pivot_table(values='sum_re_attempts',index=['has_passed_attention_to_detail'])
print temp
temp = df2.pivot_table(values='sum_re_attempts',index=['has_passed_pattern_recog'])
print temp
# Out:
# has_passed_logical_ability
# False    214.380259
# True     487.956140
# Name: sum_re_attempts, dtype: float64
# has_passed_reading_comprehension
# False    215.316640
# True     485.281525
# Name: sum_re_attempts, dtype: float64
# has_passed_general_awareness
# False    218.117647
# True     444.495000
# Name: sum_re_attempts, dtype: float64
# has_passed_attention_to_detail
# False    202.937626
# True     429.530172
# Name: sum_re_attempts, dtype: float64
# has_passed_pattern_recog
# False    220.124675
# True     373.982639
# Name: sum_re_attempts, dtype: float64

# %%
df2.boxplot(column=['qualifiers_approved','qualifiers_re_attempts','qualifiers_rejects'],by='has_passed_logical_ability',figsize=(20,25))
df2.boxplot(column=['qualifiers_approved','qualifiers_re_attempts','qualifiers_rejects'],by='has_passed_reading_comprehension',figsize=(20,25))
df2.boxplot(column=['qualifiers_approved','qualifiers_re_attempts','qualifiers_rejects'],by='has_passed_general_awareness',figsize=(20,25))
df2.boxplot(column=['qualifiers_approved','qualifiers_re_attempts','qualifiers_rejects'],by='has_passed_attention_to_detail',figsize=(20,25))
df2.boxplot(column=['qualifiers_approved','qualifiers_re_attempts','qualifiers_rejects'],by='has_passed_pattern_recog',figsize=(20,25))

'''df2.boxplot(column=['voice_approved','voice_rejects','voice_re_attempts'],by='has_passed_logical_ability',figsize=(20,20))
df2.boxplot(column=['sd_approved','sd_rejects','sd_re_attempts'],by='has_passed_logical_ability',figsize=(20,10))
df2.boxplot(column=['ts_approved','ts_rejects','ts_re_attempts'],by='has_passed_logical_ability',figsize=(20,10))
df2.boxplot(column=['other_data_rejects','other_data_re_attempts','other_data_approved'],by='has_passed_logical_ability',figsize=(20,10))'''
# Out:
# "df2.boxplot(column=['voice_approved','voice_rejects','voice_re_attempts'],by='has_passed_logical_ability',figsize=(20,20))\ndf2.boxplot(column=['sd_approved','sd_rejects','sd_re_attempts'],by='has_passed_logical_ability',figsize=(20,10))\ndf2.boxplot(column=['ts_approved','ts_rejects','ts_re_attempts'],by='has_passed_logical_ability',figsize=(20,10))\ndf2.boxplot(column=['other_data_rejects','other_data_re_attempts','other_data_approved'],by='has_passed_logical_ability',figsize=(20,10))"

# %%
df2.boxplot(column=['voice_approved','voice_rejects','voice_re_attempts'],by='has_passed_logical_ability',figsize=(20,30))
df2.boxplot(column=['voice_approved','voice_rejects','voice_re_attempts'],by='has_passed_reading_comprehension',figsize=(20,25))
df2.boxplot(column=['voice_approved','voice_rejects','voice_re_attempts'],by='has_passed_general_awareness',figsize=(20,25))
df2.boxplot(column=['voice_approved','voice_rejects','voice_re_attempts'],by='has_passed_attention_to_detail',figsize=(20,25))
df2.boxplot(column=['voice_approved','voice_rejects','voice_re_attempts'],by='has_passed_pattern_recog',figsize=(20,25))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000B8D1A58>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000A2E7CF8>]], dtype=object)

# %%
df2.boxplot(column=['sd_approved','sd_rejects','sd_re_attempts'],by='has_passed_logical_ability',figsize=(20,30))
df2.boxplot(column=['sd_approved','sd_rejects','sd_re_attempts'],by='has_passed_reading_comprehension',figsize=(20,35))
df2.boxplot(column=['sd_approved','sd_rejects','sd_re_attempts'],by='has_passed_general_awareness',figsize=(20,35))
df2.boxplot(column=['sd_approved','sd_rejects','sd_re_attempts'],by='has_passed_attention_to_detail',figsize=(20,35))
df2.boxplot(column=['sd_approved','sd_rejects','sd_re_attempts'],by='has_passed_pattern_recog',figsize=(20,35))

'''df2.boxplot(column=['voice_approved','voice_rejects','voice_re_attempts'],by='has_passed_logical_ability',figsize=(20,20))
df2.boxplot(column=['sd_approved','sd_rejects','sd_re_attempts'],by='has_passed_logical_ability',figsize=(20,10))
df2.boxplot(column=['ts_approved','ts_rejects','ts_re_attempts'],by='has_passed_logical_ability',figsize=(20,10))
df2.boxplot(column=['other_data_rejects','other_data_re_attempts','other_data_approved'],by='has_passed_logical_ability',figsize=(20,10))'''
# Out:
# "df2.boxplot(column=['voice_approved','voice_rejects','voice_re_attempts'],by='has_passed_logical_ability',figsize=(20,20))\ndf2.boxplot(column=['sd_approved','sd_rejects','sd_re_attempts'],by='has_passed_logical_ability',figsize=(20,10))\ndf2.boxplot(column=['ts_approved','ts_rejects','ts_re_attempts'],by='has_passed_logical_ability',figsize=(20,10))\ndf2.boxplot(column=['other_data_rejects','other_data_re_attempts','other_data_approved'],by='has_passed_logical_ability',figsize=(20,10))"

# %%
df2.boxplot(column=['ts_approved','ts_rejects','ts_re_attempts'],by='has_passed_logical_ability',figsize=(20,30))
df2.boxplot(column=['ts_approved','ts_rejects','ts_re_attempts'],by='has_passed_reading_comprehension',figsize=(20,25))
df2.boxplot(column=['ts_approved','ts_rejects','ts_re_attempts'],by='has_passed_general_awareness',figsize=(20,25))
df2.boxplot(column=['ts_approved','ts_rejects','ts_re_attempts'],by='has_passed_attention_to_detail',figsize=(20,25))
df2.boxplot(column=['ts_approved','ts_rejects','ts_re_attempts'],by='has_passed_pattern_recog',figsize=(20,25))

'''df2.boxplot(column=['voice_approved','voice_rejects','voice_re_attempts'],by='has_passed_logical_ability',figsize=(20,20))
df2.boxplot(column=['sd_approved','sd_rejects','sd_re_attempts'],by='has_passed_logical_ability',figsize=(20,10))
df2.boxplot(column=['ts_approved','ts_rejects','ts_re_attempts'],by='has_passed_logical_ability',figsize=(20,10))
df2.boxplot(column=['other_data_rejects','other_data_re_attempts','other_data_approved'],by='has_passed_logical_ability',figsize=(20,10))'''
# Out:
# "df2.boxplot(column=['voice_approved','voice_rejects','voice_re_attempts'],by='has_passed_logical_ability',figsize=(20,20))\ndf2.boxplot(column=['sd_approved','sd_rejects','sd_re_attempts'],by='has_passed_logical_ability',figsize=(20,10))\ndf2.boxplot(column=['ts_approved','ts_rejects','ts_re_attempts'],by='has_passed_logical_ability',figsize=(20,10))\ndf2.boxplot(column=['other_data_rejects','other_data_re_attempts','other_data_approved'],by='has_passed_logical_ability',figsize=(20,10))"

# %%
df2.boxplot(column=['other_data_rejects','other_data_re_attempts','other_data_approved'],by='has_passed_logical_ability',
            figsize=(20,30))
df2.boxplot(column=['other_data_rejects','other_data_re_attempts','other_data_approved'],by='has_passed_reading_comprehension',figsize=(20,25))
df2.boxplot(column=['other_data_rejects','other_data_re_attempts','other_data_approved'],by='has_passed_general_awareness',figsize=(20,25))
df2.boxplot(column=['other_data_rejects','other_data_re_attempts','other_data_approved'],by='has_passed_attention_to_detail',figsize=(20,25))
df2.boxplot(column=['other_data_rejects','other_data_re_attempts','other_data_approved'],by='has_passed_pattern_recog',figsize=(20,25))

'''df2.boxplot(column=['voice_approved','voice_rejects','voice_re_attempts'],by='has_passed_logical_ability',figsize=(20,1000))
df2.boxplot(column=['sd_approved','sd_rejects','sd_re_attempts'],by='has_passed_logical_ability',figsize=(20,10))
df2.boxplot(column=['ts_approved','ts_rejects','ts_re_attempts'],by='has_passed_logical_ability',figsize=(20,10))
df2.boxplot(column=['other_data_rejects','other_data_re_attempts','other_data_approved'],by='has_passed_logical_ability',figsize=(20,10))'''
# Out:
# "df2.boxplot(column=['voice_approved','voice_rejects','voice_re_attempts'],by='has_passed_logical_ability',figsize=(20,1000))\ndf2.boxplot(column=['sd_approved','sd_rejects','sd_re_attempts'],by='has_passed_logical_ability',figsize=(20,10))\ndf2.boxplot(column=['ts_approved','ts_rejects','ts_re_attempts'],by='has_passed_logical_ability',figsize=(20,10))\ndf2.boxplot(column=['other_data_rejects','other_data_re_attempts','other_data_approved'],by='has_passed_logical_ability',figsize=(20,10))"
